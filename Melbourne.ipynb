# %% [markdown]
# Import the Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading the Data

# %%
df = pd.read_csv("Melbourne_housing_FULL.csv")

# %% [markdown]
# Number of Rows and Columns

# %% [markdown]
# Some Key Details
# Suburb: Suburb
#
# Address: Address
#
# Rooms: Number of rooms
#
# Price: Price in dollars
#
# Method: S - property sold; SP - property sold prior; PI - property passed in; PN - sold prior not disclosed; SN - sold not disclosed; NB - no bid; VB - vendor bid; W - withdrawn prior to auction; SA - sold after auction; SS - sold after auction price not disclosed. N/A - price or highest bid not available.
#
# Type: br - bedroom(s); h - house,cottage,villa, semi,terrace; u - unit, duplex; t - townhouse; dev site - development site; o res - other residential.
#
# SellerG: Real Estate Agent
#
# Date: Date sold
#
# Distance: Distance from CBD
#
# Regionname: General Region (West, North West, North, North east ...etc)
#
# Propertycount: Number of properties that exist in the suburb.
#
# Bedroom2 : Scraped # of Bedrooms (from different source)
#
# Bathroom: Number of Bathrooms
#
# Car: Number of carspots
#
# Landsize: Land Size
#
# BuildingArea: Building Size
#
# YearBuilt: Year the house was built
#
# CouncilArea: Governing council for the area
#
# Lattitude: Self explanitory
#
# Longtitude: Self explanitory

# %%
df.shape
# Out:
# (34857, 21)

# %% [markdown]
# View first few Samples

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode      ...       Bathroom  Car  Landsize  \
# 0  3/09/2016       2.5    3067.0      ...            1.0  1.0     126.0
# 1  3/12/2016       2.5    3067.0      ...            1.0  1.0     202.0
# 2  4/02/2016       2.5    3067.0      ...            1.0  0.0     156.0
# 3  4/02/2016       2.5    3067.0      ...            2.0  1.0       0.0
# 4  4/03/2017       2.5    3067.0      ...            2.0  0.0     134.0
#
#    BuildingArea  YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %% [markdown]
# Statistical Information

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %% [markdown]
# Count gives information on missing Values

# %%
df.isnull().mean()
# Out:
# Suburb           0.000000
# Address          0.000000
# Rooms            0.000000
# Type             0.000000
# Price            0.218321
# Method           0.000000
# SellerG          0.000000
# Date             0.000000
# Distance         0.000029
# Postcode         0.000029
# Bedroom2         0.235735
# Bathroom         0.235993
# Car              0.250394
# Landsize         0.338813
# BuildingArea     0.605761
# YearBuilt        0.553863
# CouncilArea      0.000086
# Lattitude        0.228821
# Longtitude       0.228821
# Regionname       0.000086
# Propertycount    0.000086
# dtype: float64

# %%
df_na = df.isnull().mean()
df_na = pd.DataFrame(df_na.reset_index())
df_na.columns=['variable', 'na_perc']

# %%
df_na
# Out:
#          variable   na_perc
# 0          Suburb  0.000000
# 1         Address  0.000000
# 2           Rooms  0.000000
# 3            Type  0.000000
# 4           Price  0.218321
# 5          Method  0.000000
# 6         SellerG  0.000000
# 7            Date  0.000000
# 8        Distance  0.000029
# 9        Postcode  0.000029
# 10       Bedroom2  0.235735
# 11       Bathroom  0.235993
# 12            Car  0.250394
# 13       Landsize  0.338813
# 14   BuildingArea  0.605761
# 15      YearBuilt  0.553863
# 16    CouncilArea  0.000086
# 17      Lattitude  0.228821
# 18     Longtitude  0.228821
# 19     Regionname  0.000086
# 20  Propertycount  0.000086

# %%
df_na.shape[0]
# Out:
# 21

# %%
df_na[df_na.na_perc!=0].shape[0]
# Out:
# 14

# %%
df.dropna().shape[0]
# Out:
# 8887

# %%
df_na.index = df_na['variable']
df_na[df_na.na_perc!=0].sort_values(by="na_perc",ascending = False).plot.bar()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34857 entries, 0 to 34856
# Data columns (total 21 columns):
# Suburb           34857 non-null object
# Address          34857 non-null object
# Rooms            34857 non-null int64
# Type             34857 non-null object
# Price            27247 non-null float64
# Method           34857 non-null object
# SellerG          34857 non-null object
# Date             34857 non-null object
# Distance         34856 non-null float64
# Postcode         34856 non-null float64
# Bedroom2         26640 non-null float64
# Bathroom         26631 non-null float64
# Car              26129 non-null float64
# Landsize         23047 non-null float64
# BuildingArea     13742 non-null float64
# YearBuilt        15551 non-null float64
# CouncilArea      34854 non-null object
# Lattitude        26881 non-null float64
# Longtitude       26881 non-null float64
# Regionname       34854 non-null object
# Propertycount    34854 non-null float64
# ...

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# Categorical variables

# %% [markdown]
# 'Suburb', 'Address','Type', 'Method', 'SellerG','Date',  'Postcode','YearBuilt', 'CouncilArea', 'Regionname'

# %% [markdown]
# Dummy Variables for region name and type of house

# %%
#x = df[['Rooms', 'Type', 'Distance',  'Bedroom2', 'Bathroom',
                #'Car','Landsize', 'BuildingArea', 'Lattitude','Longtitude', 'Regionname']]

# %%
#y = df['Price']

# %%
#x.corr()

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(), annot = True, cbar = False, linewidth = 1)

# %%
df = pd.get_dummies(df, columns = ['Regionname','Type'])

# %%
df
# Out:
#                    Suburb              Address  Rooms      Price Method  \
# 0              Abbotsford        68 Studley St      2        NaN     SS
# 1              Abbotsford         85 Turner St      2  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3        NaN     VB
# 4              Abbotsford         5 Charles St      3  1465000.0     SP
# 5              Abbotsford     40 Federation La      3   850000.0     PI
# 6              Abbotsford          55a Park St      4  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4        NaN     SN
# 8              Abbotsford         53 Turner St      2        NaN      S
# 9              Abbotsford         99 Turner St      2        NaN      S
# 10             Abbotsford       129 Charles St      2   941000.0      S
# 11             Abbotsford         124 Yarra St      3  1876000.0      S
# ...

# %% [markdown]
# Avoid dummy trap

# %%
df = df.drop(columns = "Regionname_Western Victoria")

# %%
df = df.drop(columns = 'Type_h')

# %%
df
# Out:
#                    Suburb              Address  Rooms      Price Method  \
# 0              Abbotsford        68 Studley St      2        NaN     SS
# 1              Abbotsford         85 Turner St      2  1480000.0      S
# 2              Abbotsford      25 Bloomburg St      2  1035000.0      S
# 3              Abbotsford   18/659 Victoria St      3        NaN     VB
# 4              Abbotsford         5 Charles St      3  1465000.0     SP
# 5              Abbotsford     40 Federation La      3   850000.0     PI
# 6              Abbotsford          55a Park St      4  1600000.0     VB
# 7              Abbotsford         16 Maugie St      4        NaN     SN
# 8              Abbotsford         53 Turner St      2        NaN      S
# 9              Abbotsford         99 Turner St      2        NaN      S
# 10             Abbotsford       129 Charles St      2   941000.0      S
# 11             Abbotsford         124 Yarra St      3  1876000.0      S
# ...

# %% [markdown]
# Splitting the Variables as predictor variable and target variable

# %%
df.columns
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Price', 'Method', 'SellerG', 'Date',
#        'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude',
#        'Propertycount', 'Regionname_Eastern Metropolitan',
#        'Regionname_Eastern Victoria', 'Regionname_Northern Metropolitan',
#        'Regionname_Northern Victoria', 'Regionname_South-Eastern Metropolitan',
#        'Regionname_Southern Metropolitan', 'Regionname_Western Metropolitan',
#        'Type_t', 'Type_u'],
#       dtype='object')

# %%
x = df[['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize',
       'BuildingArea', 'Lattitude', 'Longtitude', 'Regionname_Eastern Metropolitan',
       'Regionname_Eastern Victoria', 'Regionname_Northern Metropolitan',
       'Regionname_Northern Victoria', 'Regionname_South-Eastern Metropolitan',
       'Regionname_Southern Metropolitan', 'Regionname_Western Metropolitan',
       'Type_t', 'Type_u']]

# %%
y = df['Price']

# %% [markdown]
# Splitting the Predictor into target and test set

# %%
from sklearn.model_selection import train_test_split

# %%
 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
x.shape,y.shape
# Out:
# ((34857, 18), (34857,))

# %%
#Imputation mean or median shld be calculated on train set and later substituted in test set

# %%
x_train
# Out:
#        Rooms  Distance  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 3372       3       7.8       4.0       1.0  1.0     417.0         135.0
# 27417      3       6.4       2.0       1.0  1.0       NaN           NaN
# 21317      3      25.2       NaN       NaN  NaN       NaN           NaN
# 5194       1       4.6       1.0       1.0  1.0       0.0          63.0
# 16910      3       7.5       3.0       3.0  1.0     846.0         187.0
# 23424      2      15.2       NaN       NaN  NaN       NaN           NaN
# 32424      5      14.7       5.0       3.0  2.0     392.0         324.0
# 9520       3       6.1       3.0       2.0  2.0     128.0         183.0
# 21604      3      14.7       3.0       1.0  2.0       NaN           NaN
# 27576      3      14.0       3.0       1.0  1.0       NaN           NaN
# 9561       2       6.1       2.0       1.0  1.0       0.0          65.0
# 11026      2       9.5       NaN       NaN  NaN       NaN           NaN
# ...
